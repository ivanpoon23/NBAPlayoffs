# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import pandas as pd
from urllib.request import urlopen
import lxml
import time

# %% [markdown]
# This is finding the 2023 Advanced Playoff Stats off of Basketball Reference

# %%
url = "https://www.basketball-reference.com/playoffs/NBA_2023_advanced.html"

# Send an HTTP GET request to the website
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
for table in soup.find_all('table'):
    print(table.get('class'))
# Out:
# ['sortable', 'stats_table']

# %%
tables = soup.find_all('table')
table = soup.find('table', class_ = 'sortable')
for row in table.tbody.find_all('tr'):
    columns = row.find_all('td')
    if columns != []:
        print(columns[0].text.strip())
# Out:
# Bam Adebayo
# Santi Aldama
# Nickeil Alexander-Walker
# Grayson Allen
# Jarrett Allen
# Kyle Anderson
# Giannis Antetokounmpo
# Thanasis Antetokounmpo
# Deandre Ayton
# Patrick Baldwin Jr.
# Mo Bamba
# Desmond Bane
# Harrison Barnes
# RJ Barrett
# Nicolas Batum
# Malik Beasley
# MarJon Beauchamp
# Saddiq Bey
# Bismack Biyombo
# Bogdan Bogdanović
# Devin Booker
# Brandon Boston Jr.
# Christian Braun
# Mikal Bridges
# Malcolm Brogdon
# Dillon Brooks
# Bruce Brown
# Jaylen Brown
# Troy Brown Jr.
# Jalen Brunson
# Thomas Bryant
# Jimmy Butler
# Kentavious Caldwell-Pope
# Vlatko Čančar
# Clint Capela
# Jevon Carter
# Justin Champagnie
# Max Christie
# Nic Claxton
# Amir Coffey
# John Collins
# Mike Conley
# Pat Connaughton
# Robert Covington
# Torrey Craig
# Jae Crowder
# Seth Curry
# Stephen Curry
# Anthony Davis
# Terence Davis
# Dewayne Dedmon
# Spencer Dinwiddie
# Donte DiVincenzo
# PJ Dozier
# Goran Dragić
# David Duke Jr.
# Kevin Durant
# Anthony Edwards
# Kessler Edwards
# Joel Embiid
# Dorian Finney-Smith
# De'Aaron Fox
# Wenyen Gabriel
# Darius Garland
# Rudy Gobert
# Aaron Gordon
# Eric Gordon
# Danny Green
# Draymond Green
# JaMychal Green
# Jeff Green
# Blake Griffin
# Quentin Grimes
# Rui Hachimura
# James Harden
# Montrezl Harrell
# Joe Harris
# Tobias Harris
# Shaquille Harrison
# Josh Hart
# Isaiah Hartenstein
# Udonis Haslem
# Sam Hauser
# Tyler Herro
# Haywood Highsmith
# Aaron Holiday
# Jrue Holiday
# Al Horford
# Danuel House Jr.
# Kevin Huerter
# De'Andre Hunter
# Bones Hyland
# Joe Ingles
# Jaren Jackson Jr.
# Reggie Jackson
# LeBron James
# DaQuan Jeffries
# Cameron Johnson
# Jalen Johnson
# Nikola Jokić
# Tyus Jones
# DeAndre Jordan
# Nikola Jović
# Luke Kennard
# Nathan Knight
# John Konchar
# Furkan Korkmaz
# Luke Kornet
# Jonathan Kuminga
# Anthony Lamb
# Jock Landale
# Damion Lee
# Alex Len
# Kawhi Leonard
# Meyers Leonard
# Caris LeVert
# Kenneth Lofton Jr.
# Kevon Looney
# Brook Lopez
# Robin Lopez
# Kevin Love
# Kyle Lowry
# Trey Lyles
# Terance Mann
# Caleb Martin
# Wesley Matthews
# Tyrese Maxey
# Miles McBride
# Jalen McDaniels
# Jordan McLaughlin
# De'Anthony Melton
# Chimezie Metu
# Khris Middleton
# Patty Mills
# Shake Milton
# Josh Minott
# Davion Mitchell
# Donovan Mitchell
# Evan Mobley
# Malik Monk
# Moses Moody
# Wendell Moore Jr.
# Ja Morant
# Marcus Morris
# Dejounte Murray
# Jamal Murray
# Keegan Murray
# Mike Muscala
# Raul Neto
# Georges Niang
# Zeke Nnaji
# Jaylen Nowell
# Royce O'Neale
# Josh Okogie
# Onyeka Okongwu
# Isaac Okoro
# Victor Oladipo
# Cedi Osman
# Chris Paul
# Cameron Payne
# Gary Payton II
# Mason Plumlee
# Jordan Poole
# Michael Porter Jr.
# Bobby Portis
# Norman Powell
# Jason Preston
# Taurean Prince
# Payton Pritchard
# Immanuel Quickley
# Julius Randle
# Austin Reaves
# Paul Reed
# Austin Rivers
# Duncan Robinson
# Mitchell Robinson
# David Roddy
# Derrick Rose
# Terrence Ross
# Ricky Rubio
# D'Angelo Russell
# Domantas Sabonis
# Dennis Schröder
# Landry Shamet
# Day'Ron Sharpe
# Marcus Smart
# Ish Smith
# Jaden Springer
# Lamar Stevens
# Max Strus
# Edmond Sumner
# Jayson Tatum
# Cam Thomas
# Klay Thompson
# Tristan Thompson
# Xavier Tillman Sr.
# Obi Toppin
# Karl-Anthony Towns
# P.J. Tucker
# Jarred Vanderbilt
# Gabe Vincent
# Dean Wade
# Ish Wainright
# Lonnie Walker IV
# T.J. Warren
# Yuta Watanabe
# Peyton Watson
# Russell Westbrook
# Derrick White
# Andrew Wiggins
# Grant Williams
# Robert Williams
# Ziaire Williams
# Trae Young
# Omer Yurtseven
# Cody Zeller
# Ivica Zubac

# %%
tables = soup.find_all('table')
table = soup.find('table', class_ = 'sortable')

playoffs_advanced23 = pd.DataFrame(columns=['Player','Pos',	'Age','Tm', 'G', 'MP','PER', 'TS%','3PAr','FTr','ORB%','DRB%', 'TRB%','AST%','STL%','BLK%',	'TOV%',	'USG%','OWS', 'DWS','WS','WS/48','OBPM','DBPM','BPM','VORP'])

i = 0
for row in table.tbody.find_all('tr'):
    columns = row.find_all('td')
    if columns != []:
            Player = str(columns[0].text.strip())
            Pos = str(columns[1].text.strip())
            Age = int(columns[2].text.strip())
            Tm = str(columns[3].text.strip())
            G = int(columns[4].text.strip())
            MP =  columns[5].text.strip()
            PER =  columns[6].text.strip()
            ts =  columns[7].text.strip()
            PAr =  columns[8].text.strip()
            ft =  columns[9].text.strip()
            orb =  columns[10].text.strip()
            drb =  columns[11].text.strip() 
            trb =  columns[12].text.strip() 
            ast =  columns[13].text.strip() 
            stl =  columns[14].text.strip() 
            blk =  columns[15].text.strip() 
            tov =  columns[16].text.strip() 
            usg =  columns[17].text.strip() 
            ows =  columns[19].text.strip() 
            dws =  columns[20].text.strip()
            ws =  columns[21].text.strip()
            wsper =  columns[22].text.strip()
            obpm =  columns[24].text.strip()
            dbpm =  columns[25].text.strip() 
            bpm =  columns[26].text.strip()
            vrop =  columns[27].text.strip()

            playoffs_advanced23.loc[i] = [Player, Pos,Age,Tm, G, MP,PER, ts,PAr, ft, orb,drb,trb, ast,stl,blk, tov,usg,ows, dws,ws,wsper,obpm,dbpm,bpm,vrop]
            i+= 1
print(playoffs_advanced23)
# Out:
#                        Player Pos  Age   Tm   G   MP   PER   TS%  3PAr   FTr  \
# 0                 Bam Adebayo   C   25  MIA  23  850  15.8  .530  .009  .274
# 1                Santi Aldama  PF   22  MEM   6  101  15.0  .576  .455  .061
# 2    Nickeil Alexander-Walker  SG   24  MIN   5  148   7.7  .578  .714  .086
# 3               Grayson Allen  SG   27  MIL   5  149  11.0  .658  .707  .171
# 4               Jarrett Allen   C   24  CLE   5  191  13.9  .608  .000  .167
# ..                        ...  ..  ...  ...  ..  ...   ...   ...   ...   ...
# 212           Ziaire Williams  SF   21  MEM   4   12  -2.4  .357  .429  .000
# 213                Trae Young  PG   24  ATL   6  230  21.1  .521  .362  .289
# 214            Omer Yurtseven   C   24  MIA   8   16   5.5  .286  .286  .000
# 215               Cody Zeller   C   30  MIA  21  174   7.5  .553  .000  .429
# 216               Ivica Zubac   C   25  LAC   5  130  14.1  .621  .000  .533
#
#      ...  TOV%  USG%   OWS  DWS    WS   WS/48  OBPM  DBPM    BPM  VORP
# 0    ...  13.8  23.8   0.3  1.1   1.4    .078  -1.2   0.5   -0.7   0.3
# 1    ...   5.6  14.9   0.2  0.1   0.3    .139   2.3   1.7    4.0   0.2
# 2    ...   9.9  12.6   0.0  0.0   0.0    .011  -1.9   0.0   -1.9   0.0
# 3    ...   8.3  13.6   0.2  0.0   0.2    .073  -0.2  -1.0   -1.1   0.0
# 4    ...   7.2  10.2   0.3  0.3   0.6    .150   0.6   1.8    2.4   0.2
# ..   ...   ...   ...   ...  ...   ...     ...   ...   ...    ...   ...
# 212  ...  22.2  31.4  -0.1  0.0  -0.1  -0.275  -6.3  -1.9   -8.2   0.0
# 213  ...  12.5  34.3   0.3  0.0   0.3    .066   4.7  -1.1    3.6   0.3
# 214  ...  12.5  22.5  -0.1  0.0   0.0  -0.113  -8.6  -4.5  -13.1   0.0
# 215  ...  23.8  14.1  -0.1  0.2   0.1    .024  -6.7  -0.1   -6.8  -0.2
# 216  ...  22.9  15.5   0.1  0.0   0.1    .041  -1.2  -1.0   -2.3   0.0
#
# [217 rows x 26 columns]

# %%
for column in playoffs_advanced23:
    if(column != 'Player' and column !='Pos'and column !='Tm'):
        playoffs_advanced23[column] = pd.to_numeric(playoffs_advanced23[column], downcast = 'float', errors = 'coerce')
playoffs_advanced23 = playoffs_advanced23.dropna()
print(playoffs_advanced23)
# Out:
#                        Player Pos   Age   Tm     G     MP   PER    TS%   3PAr  \
# 0                 Bam Adebayo   C  25.0  MIA  23.0  850.0  15.8  0.530  0.009
# 1                Santi Aldama  PF  22.0  MEM   6.0  101.0  15.0  0.576  0.455
# 2    Nickeil Alexander-Walker  SG  24.0  MIN   5.0  148.0   7.7  0.578  0.714
# 3               Grayson Allen  SG  27.0  MIL   5.0  149.0  11.0  0.658  0.707
# 4               Jarrett Allen   C  24.0  CLE   5.0  191.0  13.9  0.608  0.000
# ..                        ...  ..   ...  ...   ...    ...   ...    ...    ...
# 212           Ziaire Williams  SF  21.0  MEM   4.0   12.0  -2.4  0.357  0.429
# 213                Trae Young  PG  24.0  ATL   6.0  230.0  21.1  0.521  0.362
# 214            Omer Yurtseven   C  24.0  MIA   8.0   16.0   5.5  0.286  0.286
# 215               Cody Zeller   C  30.0  MIA  21.0  174.0   7.5  0.553  0.000
# 216               Ivica Zubac   C  25.0  LAC   5.0  130.0  14.1  0.621  0.000
#
#        FTr  ...       TOV%       USG%  OWS  DWS   WS  WS/48  OBPM  DBPM   BPM  \
# 0    0.274  ...  13.800000  23.799999  0.3  1.1  1.4  0.078  -1.2   0.5  -0.7
# 1    0.061  ...   5.600000  14.900000  0.2  0.1  0.3  0.139   2.3   1.7   4.0
# 2    0.086  ...   9.900000  12.600000  0.0  0.0  0.0  0.011  -1.9   0.0  -1.9
# 3    0.171  ...   8.300000  13.600000  0.2  0.0  0.2  0.073  -0.2  -1.0  -1.1
# 4    0.167  ...   7.200000  10.200000  0.3  0.3  0.6  0.150   0.6   1.8   2.4
# ..     ...  ...        ...        ...  ...  ...  ...    ...   ...   ...   ...
# 212  0.000  ...  22.200001  31.400000 -0.1  0.0 -0.1 -0.275  -6.3  -1.9  -8.2
# 213  0.289  ...  12.500000  34.299999  0.3  0.0  0.3  0.066   4.7  -1.1   3.6
# 214  0.000  ...  12.500000  22.500000 -0.1  0.0  0.0 -0.113  -8.6  -4.5 -13.1
# 215  0.429  ...  23.799999  14.100000 -0.1  0.2  0.1  0.024  -6.7  -0.1  -6.8
# 216  0.533  ...  22.900000  15.500000  0.1  0.0  0.1  0.041  -1.2  -1.0  -2.3
#
#      VORP
# 0     0.3
# 1     0.2
# 2     0.0
# 3     0.0
# 4     0.2
# ..    ...
# 212   0.0
# 213   0.3
# 214   0.0
# 215  -0.2
# 216   0.0
#
# [207 rows x 26 columns]

# %%
#Most Impactful Players
filtered_minutes_played23 = playoffs_advanced23[playoffs_advanced23['MP']>50]
print(filtered_minutes_played23)
# Out:
#                        Player Pos   Age   Tm     G     MP   PER    TS%   3PAr  \
# 0                 Bam Adebayo   C  25.0  MIA  23.0  850.0  15.8  0.530  0.009
# 1                Santi Aldama  PF  22.0  MEM   6.0  101.0  15.0  0.576  0.455
# 2    Nickeil Alexander-Walker  SG  24.0  MIN   5.0  148.0   7.7  0.578  0.714
# 3               Grayson Allen  SG  27.0  MIL   5.0  149.0  11.0  0.658  0.707
# 4               Jarrett Allen   C  24.0  CLE   5.0  191.0  13.9  0.608  0.000
# ..                        ...  ..   ...  ...   ...    ...   ...    ...    ...
# 210            Grant Williams  PF  24.0  BOS  15.0  265.0  12.0  0.662  0.755
# 211           Robert Williams   C  25.0  BOS  20.0  417.0  19.6  0.786  0.012
# 213                Trae Young  PG  24.0  ATL   6.0  230.0  21.1  0.521  0.362
# 215               Cody Zeller   C  30.0  MIA  21.0  174.0   7.5  0.553  0.000
# 216               Ivica Zubac   C  25.0  LAC   5.0  130.0  14.1  0.621  0.000
#
#        FTr  ...       TOV%       USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  \
# 0    0.274  ...  13.800000  23.799999  0.3  1.1  1.4  0.078  -1.2   0.5 -0.7
# 1    0.061  ...   5.600000  14.900000  0.2  0.1  0.3  0.139   2.3   1.7  4.0
# 2    0.086  ...   9.900000  12.600000  0.0  0.0  0.0  0.011  -1.9   0.0 -1.9
# 3    0.171  ...   8.300000  13.600000  0.2  0.0  0.2  0.073  -0.2  -1.0 -1.1
# 4    0.167  ...   7.200000  10.200000  0.3  0.3  0.6  0.150   0.6   1.8  2.4
# ..     ...  ...        ...        ...  ...  ...  ...    ...   ...   ...  ...
# 210  0.189  ...   6.500000  10.500000  0.6  0.2  0.8  0.137   0.1   1.0  1.1
# 211  0.329  ...  14.100000  12.300000  1.2  0.6  1.8  0.208   0.6   2.7  3.4
# 213  0.289  ...  12.500000  34.299999  0.3  0.0  0.3  0.066   4.7  -1.1  3.6
# 215  0.429  ...  23.799999  14.100000 -0.1  0.2  0.1  0.024  -6.7  -0.1 -6.8
# 216  0.533  ...  22.900000  15.500000  0.1  0.0  0.1  0.041  -1.2  -1.0 -2.3
#
#      VORP
# 0     0.3
# 1     0.2
# 2     0.0
# 3     0.0
# 4     0.2
# ..    ...
# 210   0.2
# 211   0.6
# 213   0.3
# 215  -0.2
# 216   0.0
#
# [147 rows x 26 columns]

# %% [markdown]
# This is finding the 2022 Advanced Playoff Stats off of Basketball Reference

# %%
url = "https://www.basketball-reference.com/playoffs/NBA_2022_advanced.html"

# Send an HTTP GET request to the website
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
for table in soup.find_all('table'):
    print(table.get('class'))
# Out:
# ['sortable', 'stats_table']

# %%
tables = soup.find_all('table')
table = soup.find('table', class_ = 'sortable')

playoffs_advanced22 = pd.DataFrame(columns=['Player','Pos',	'Age','Tm', 'G', 'MP','PER', 'TS%','3PAr','FTr','ORB%','DRB%', 'TRB%','AST%','STL%','BLK%',	'TOV%',	'USG%','OWS', 'DWS','WS','WS/48','OBPM','DBPM','BPM','VORP'])

i = 0
for row in table.tbody.find_all('tr'):
    columns = row.find_all('td')
    if columns != []:
            Player = str(columns[0].text.strip())
            Pos = str(columns[1].text.strip())
            Age = int(columns[2].text.strip())
            Tm = str(columns[3].text.strip())
            G = int(columns[4].text.strip())
            MP =  columns[5].text.strip()
            PER =  columns[6].text.strip()
            ts =  columns[7].text.strip()
            PAr =  columns[8].text.strip()
            ft =  columns[9].text.strip()
            orb =  columns[10].text.strip()
            drb =  columns[11].text.strip() 
            trb =  columns[12].text.strip() 
            ast =  columns[13].text.strip() 
            stl =  columns[14].text.strip() 
            blk =  columns[15].text.strip() 
            tov =  columns[16].text.strip() 
            usg =  columns[17].text.strip() 
            ows =  columns[19].text.strip() 
            dws =  columns[20].text.strip()
            ws =  columns[21].text.strip()
            wsper =  columns[22].text.strip()
            obpm =  columns[24].text.strip()
            dbpm =  columns[25].text.strip() 
            bpm =  columns[26].text.strip()
            vrop =  columns[27].text.strip()

            playoffs_advanced22.loc[i] = [Player, Pos,Age,Tm, G, MP,PER, ts,PAr, ft, orb,drb,trb, ast,stl,blk, tov,usg,ows, dws,ws,wsper,obpm,dbpm,bpm,vrop]
            i+= 1

for column in playoffs_advanced22:
    if(column != 'Player' and column !='Pos'and column !='Tm'):
        playoffs_advanced22[column] = pd.to_numeric(playoffs_advanced22[column], downcast = 'float', errors = 'coerce')
playoffs_advanced22 = playoffs_advanced22.dropna()
print(playoffs_advanced22)
# Out:
#                        Player Pos   Age   Tm     G     MP        PER    TS%  \
# 0            Precious Achiuwa   C  22.0  TOR   6.0  167.0  10.900000  0.541
# 1                Steven Adams   C  28.0  MEM   7.0  114.0  12.800000  0.464
# 2                 Bam Adebayo   C  24.0  MIA  18.0  614.0  17.900000  0.638
# 3    Nickeil Alexander-Walker  SG  23.0  UTA   1.0    5.0  66.500000  1.025
# 4               Grayson Allen  SG  26.0  MIL  12.0  305.0  10.300000  0.576
# ..                        ...  ..   ...  ...   ...    ...        ...    ...
# 212           Ziaire Williams  SF  20.0  MEM  10.0  168.0  11.800000  0.598
# 213              Delon Wright  SG  29.0  ATL   5.0  137.0  15.900000  0.622
# 214            Thaddeus Young  PF  33.0  TOR   6.0   87.0  14.300000  0.506
# 215                Trae Young  PG  23.0  ATL   5.0  186.0   5.300000  0.461
# 216            Omer Yurtseven   C  23.0  MIA   9.0   38.0  25.799999  0.647
#
#       3PAr    FTr  ...  TOV%       USG%  OWS  DWS   WS  WS/48       OBPM  \
# 0    0.308  0.192  ...  13.8  18.200001  0.0  0.0  0.0 -0.014  -2.400000
# 1    0.000  0.524  ...  13.4  10.700000  0.2  0.2  0.3  0.128  -1.600000
# 2    0.006  0.434  ...  15.4  17.900000  1.2  1.0  2.2  0.169   0.900000
# 3    0.000  0.500  ...   0.0  22.900000  0.1  0.0  0.1  0.810  27.799999
# 4    0.585  0.134  ...   9.4  13.600000  0.2  0.5  0.7  0.115  -1.000000
# ..     ...    ...  ...   ...        ...  ...  ...  ...    ...        ...
# 212  0.692  0.250  ...   3.3  14.600000  0.3  0.1  0.4  0.126  -0.900000
# 213  0.448  0.310  ...  13.2  12.800000  0.3  0.1  0.4  0.130   3.300000
# 214  0.389  0.222  ...  13.2  12.100000  0.1  0.0  0.1  0.067  -0.600000
# 215  0.551  0.478  ...  27.1  28.299999 -0.6  0.1 -0.5 -0.139  -4.000000
# 216  0.111  0.167  ...   0.0  22.600000  0.1  0.0  0.2  0.228   5.100000
#
#           DBPM        BPM  VORP
# 0    -1.000000  -3.300000  -0.1
# 1     0.500000  -1.100000   0.0
# 2     2.000000   2.900000   0.8
# 3    22.299999  50.099998   0.1
# 4     1.200000   0.200000   0.2
# ..         ...        ...   ...
# 212   0.400000  -0.600000   0.1
# 213   1.500000   4.800000   0.2
# 214   2.300000   1.700000   0.1
# 215  -4.100000  -8.100000  -0.3
# 216   2.800000   8.000000   0.1
#
# [210 rows x 26 columns]

# %%
filtered_minutes_played_22 = playoffs_advanced22[playoffs_advanced22['MP']>50]
print(filtered_minutes_played_22)
# Out:
#                Player Pos   Age   Tm     G     MP        PER    TS%   3PAr  \
# 0    Precious Achiuwa   C  22.0  TOR   6.0  167.0  10.900000  0.541  0.308
# 1        Steven Adams   C  28.0  MEM   7.0  114.0  12.800000  0.464  0.000
# 2         Bam Adebayo   C  24.0  MIA  18.0  614.0  17.900000  0.638  0.006
# 4       Grayson Allen  SG  26.0  MIL  12.0  305.0  10.300000  0.576  0.585
# 5       Jose Alvarado  PG  23.0  NOP   6.0  117.0  13.300000  0.620  0.485
# ..                ...  ..   ...  ...   ...    ...        ...    ...    ...
# 211   Robert Williams   C  24.0  BOS  17.0  394.0  21.700001  0.725  0.013
# 212   Ziaire Williams  SF  20.0  MEM  10.0  168.0  11.800000  0.598  0.692
# 213      Delon Wright  SG  29.0  ATL   5.0  137.0  15.900000  0.622  0.448
# 214    Thaddeus Young  PF  33.0  TOR   6.0   87.0  14.300000  0.506  0.389
# 215        Trae Young  PG  23.0  ATL   5.0  186.0   5.300000  0.461  0.551
#
#        FTr  ...  TOV%       USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 0    0.192  ...  13.8  18.200001  0.0  0.0  0.0 -0.014  -2.4  -1.0 -3.3  -0.1
# 1    0.524  ...  13.4  10.700000  0.2  0.2  0.3  0.128  -1.6   0.5 -1.1   0.0
# 2    0.434  ...  15.4  17.900000  1.2  1.0  2.2  0.169   0.9   2.0  2.9   0.8
# 4    0.134  ...   9.4  13.600000  0.2  0.5  0.7  0.115  -1.0   1.2  0.2   0.2
# 5    0.394  ...  15.3  16.799999  0.2  0.0  0.2  0.090  -1.8   1.7 -0.1   0.1
# ..     ...  ...   ...        ...  ...  ...  ...    ...   ...   ...  ...   ...
# 211  0.359  ...  10.0  11.500000  1.3  0.8  2.1  0.254   2.2   3.8  5.9   0.8
# 212  0.250  ...   3.3  14.600000  0.3  0.1  0.4  0.126  -0.9   0.4 -0.6   0.1
# 213  0.310  ...  13.2  12.800000  0.3  0.1  0.4  0.130   3.3   1.5  4.8   0.2
# 214  0.222  ...  13.2  12.100000  0.1  0.0  0.1  0.067  -0.6   2.3  1.7   0.1
# 215  0.478  ...  27.1  28.299999 -0.6  0.1 -0.5 -0.139  -4.0  -4.1 -8.1  -0.3
#
# [160 rows x 26 columns]

# %% [markdown]
# This is the 2024 Advanced Playoffs Data

# %%
url = "https://www.basketball-reference.com/playoffs/NBA_2024_advanced.html"

# Send an HTTP GET request to the website
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
tables = soup.find_all('table')
table = soup.find('table', class_ = 'sortable')

playoffs_advanced24 = pd.DataFrame(columns=['Player','Pos',	'Age','Tm', 'G', 'MP','PER', 'TS%','3PAr','FTr','ORB%','DRB%', 'TRB%','AST%','STL%','BLK%',	'TOV%',	'USG%','OWS', 'DWS','WS','WS/48','OBPM','DBPM','BPM','VORP'])

i = 0
for row in table.tbody.find_all('tr'):
    columns = row.find_all('td')
    if columns != []:
            Player = str(columns[0].text.strip())
            Pos = str(columns[1].text.strip())
            Age = int(columns[2].text.strip())
            Tm = str(columns[3].text.strip())
            G = int(columns[4].text.strip())
            MP =  columns[5].text.strip()
            PER =  columns[6].text.strip()
            ts =  columns[7].text.strip()
            PAr =  columns[8].text.strip()
            ft =  columns[9].text.strip()
            orb =  columns[10].text.strip()
            drb =  columns[11].text.strip() 
            trb =  columns[12].text.strip() 
            ast =  columns[13].text.strip() 
            stl =  columns[14].text.strip() 
            blk =  columns[15].text.strip() 
            tov =  columns[16].text.strip() 
            usg =  columns[17].text.strip() 
            ows =  columns[19].text.strip() 
            dws =  columns[20].text.strip()
            ws =  columns[21].text.strip()
            wsper =  columns[22].text.strip()
            obpm =  columns[24].text.strip()
            dbpm =  columns[25].text.strip() 
            bpm =  columns[26].text.strip()
            vrop =  columns[27].text.strip()

            playoffs_advanced24.loc[i] = [Player, Pos,Age,Tm, G, MP,PER, ts,PAr, ft, orb,drb,trb, ast,stl,blk, tov,usg,ows, dws,ws,wsper,obpm,dbpm,bpm,vrop]
            i+= 1

for column in playoffs_advanced24:
    if(column != 'Player' and column !='Pos'and column !='Tm'):
        playoffs_advanced24[column] = pd.to_numeric(playoffs_advanced24[column], downcast = 'float', errors = 'coerce')
playoffs_advanced24 = playoffs_advanced24.dropna()
print(playoffs_advanced24)
# Out:
#                        Player Pos   Age   Tm     G     MP        PER    TS%  \
# 0            Precious Achiuwa  PF  24.0  NYK   9.0  184.0  12.400000  0.482
# 1                 Bam Adebayo   C  26.0  MIA   5.0  192.0  18.200001  0.532
# 2    Nickeil Alexander-Walker  SG  25.0  MIN  16.0  378.0   8.700000  0.498
# 3               Grayson Allen  SG  28.0  PHO   2.0   43.0   4.500000  0.518
# 4               Jarrett Allen   C  25.0  CLE   4.0  127.0  27.100000  0.702
# ..                        ...  ..   ...  ...   ...    ...        ...    ...
# 207            Jalen Williams  PF  22.0  OKC  10.0  377.0  17.799999  0.544
# 208           Jaylin Williams   C  21.0  OKC  10.0  127.0  16.500000  0.633
# 209          Kenrich Williams  PF  29.0  OKC   7.0   32.0   4.600000  0.250
# 210              Delon Wright  PG  31.0  MIA   4.0  107.0  15.400000  0.766
# 212               Ivica Zubac   C  26.0  LAC   6.0  192.0  19.500000  0.615
#
#       3PAr    FTr  ...       TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  \
# 0    0.070  0.302  ...   7.600000  12.6  0.1  0.1  0.2  0.054  -3.4  -0.1
# 1    0.103  0.216  ...   7.000000  29.1  0.1  0.1  0.2  0.047   1.7   0.4
# 2    0.723  0.089  ...  11.400000  15.8  0.0  0.3  0.3  0.042  -2.1   0.8
# 3    1.000  0.800  ...  30.700001  10.6  0.0  0.0 -0.1 -0.061  -4.3  -1.2
# 4    0.000  0.703  ...   9.400000  19.6  0.5  0.3  0.8  0.284   5.8   2.5
# ..     ...    ...  ...        ...   ...  ...  ...  ...    ...   ...   ...
# 207  0.244  0.169  ...  10.000000  23.1  0.4  0.8  1.2  0.152   1.4   2.3
# 208  0.667  0.121  ...   7.900000  13.6  0.3  0.3  0.6  0.214   2.4   4.1
# 209  0.625  0.000  ...   0.000000  11.4 -0.1  0.1  0.0  0.023  -6.5   1.8
# 210  0.500  0.100  ...   0.000000   9.6  0.3  0.1  0.4  0.158   0.1   3.8
# 212  0.000  0.286  ...   9.200000  20.6  0.4  0.2  0.6  0.141   1.2   0.3
#
#      BPM  VORP
# 0   -3.5  -0.1
# 1    2.1   0.2
# 2   -1.3   0.1
# 3   -5.5   0.0
# 4    8.4   0.3
# ..   ...   ...
# 207  3.8   0.6
# 208  6.5   0.3
# 209 -4.7   0.0
# 210  3.9   0.2
# 212  1.4   0.2
#
# [205 rows x 26 columns]

# %%
filtered_minutes_played_24 = playoffs_advanced24[playoffs_advanced24['MP']>50]
print(filtered_minutes_played_24)
# Out:
#                        Player Pos   Age   Tm     G     MP        PER    TS%  \
# 0            Precious Achiuwa  PF  24.0  NYK   9.0  184.0  12.400000  0.482
# 1                 Bam Adebayo   C  26.0  MIA   5.0  192.0  18.200001  0.532
# 2    Nickeil Alexander-Walker  SG  25.0  MIN  16.0  378.0   8.700000  0.498
# 4               Jarrett Allen   C  25.0  CLE   4.0  127.0  27.100000  0.702
# 5               Jose Alvarado  PG  25.0  NOP   4.0   62.0  -0.200000  0.175
# ..                        ...  ..   ...  ...   ...    ...        ...    ...
# 206             Aaron Wiggins  SG  25.0  OKC  10.0  157.0  14.800000  0.598
# 207            Jalen Williams  PF  22.0  OKC  10.0  377.0  17.799999  0.544
# 208           Jaylin Williams   C  21.0  OKC  10.0  127.0  16.500000  0.633
# 210              Delon Wright  PG  31.0  MIA   4.0  107.0  15.400000  0.766
# 212               Ivica Zubac   C  26.0  LAC   6.0  192.0  19.500000  0.615
#
#       3PAr    FTr  ...       TOV%       USG%  OWS  DWS   WS  WS/48  OBPM  \
# 0    0.070  0.302  ...   7.600000  12.600000  0.1  0.1  0.2  0.054  -3.4
# 1    0.103  0.216  ...   7.000000  29.100000  0.1  0.1  0.2  0.047   1.7
# 2    0.723  0.089  ...  11.400000  15.800000  0.0  0.3  0.3  0.042  -2.1
# 4    0.000  0.703  ...   9.400000  19.600000  0.5  0.3  0.8  0.284   5.8
# 5    0.700  0.000  ...  16.700001  17.000000 -0.3  0.1 -0.2 -0.177  -7.8
# ..     ...    ...  ...        ...        ...  ...  ...  ...    ...   ...
# 206  0.426  0.234  ...  14.800000  17.700001  0.1  0.3  0.5  0.139   0.1
# 207  0.244  0.169  ...  10.000000  23.100000  0.4  0.8  1.2  0.152   1.4
# 208  0.667  0.121  ...   7.900000  13.600000  0.3  0.3  0.6  0.214   2.4
# 210  0.500  0.100  ...   0.000000   9.600000  0.3  0.1  0.4  0.158   0.1
# 212  0.000  0.286  ...   9.200000  20.600000  0.4  0.2  0.6  0.141   1.2
#
#      DBPM  BPM  VORP
# 0    -0.1 -3.5  -0.1
# 1     0.4  2.1   0.2
# 2     0.8 -1.3   0.1
# 4     2.5  8.4   0.3
# 5     1.9 -6.0  -0.1
# ..    ...  ...   ...
# 206   2.1  2.2   0.2
# 207   2.3  3.8   0.6
# 208   4.1  6.5   0.3
# 210   3.8  3.9   0.2
# 212   0.3  1.4   0.2
#
# [146 rows x 26 columns]
